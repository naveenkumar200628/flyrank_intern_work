# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the Refresh / Content Opportunity Scoring lane. This is a good fit because the decision is concrete: which pages should an editor refresh first? The data has observable signals that support that decision, such as recent traffic, content age, recency, and trend direction, and the output is easy to explain to a human reviewer.

# %%
import pandas as pd
from pathlib import Path

csv_path = Path('d:/flyrank_intern_work/data/raw/content_refresh_anonymized.csv')
df = pd.read_csv(csv_path)

# A short, honest lane description in code form
lane = 'Refresh / Content Opportunity Scoring'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision is: which pages should an editor review first for refresh? The person acting on the output is an editor or content owner. A wrong recommendation costs time and attention, because the team could spend effort on a page that is not actually worth refreshing. The cost is also strategic: a missed opportunity may leave a declining page unaddressed for too long.

# %%
# A simple version of the decision frame in plain language
question = 'Which pages should an editor refresh first?'
action = 'Review and refresh the highest-priority pages'
cost_of_wrong_call = 'Wasted editor time and missed refresh opportunities'

print(question)
print(action)
print(cost_of_wrong_call)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset is worth exploring because it contains many pages with measurable traffic and clear signal. A few real numbers from the data make the lane look promising:
#
# - Rows in the starter dataset: {df.shape[0]:,}
# - Pages with at least 100 impressions in the 90-day window: {(df['impressions_90d'] >= 100).sum():,}
# - Pages with a declining trend label: {(df['trend_direction'] == 'down').sum():,}
#
# These numbers suggest there is enough traffic and enough variation to support a ranking or refresh-oriented analysis.

# %%
# Real numbers that support the lane
rows_total = df.shape[0]
visible_pages = int((df['impressions_90d'] >= 100).sum())
declining_pages = int((df['trend_direction'] == 'down').sum())

print(f'Total rows: {rows_total}')
print(f'Pages with >=100 impressions: {visible_pages}')
print(f'Pages with declining trend: {declining_pages}')

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim that this project will use observed signals from the dataset to rank pages by refresh opportunity. I can also claim that the output is decision-support, because it helps an editor prioritize work rather than prove causality. I cannot claim that the analysis proves a causal effect, that it predicts the future with certainty, or that it is a substitute for human judgment. The work will be directional and evidence-based, not a guarantee.

# %%
# Honest claim language
claims = [
    'Observed signals from the dataset will be used to score refresh opportunity.',
    'The output is decision-support for editors.',
    'The analysis is directional, not causal proof.'
]

for claim in claims:
    print(claim)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
